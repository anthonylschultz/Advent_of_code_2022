# %%
import pandas as pd

data_raw = pd.read_csv('data/6.csv', header=None)

# %%
data_raw
# Out:
#                                                    0
# 0  mgwwjddqzqdqsstctjjsdjsdsrsfsmfsfwwltwlwhwnhhl...

# %%
x = data_raw.iloc[0][0]

# %%
def check_input(lst):
    ''' 
    1) increment each chunk of four characters
    2) check each chunk if any characters are the same
    3a) if the chunk has unique characters:
    3b) count number of characters between beginning of string to end of chunk

    
    '''

# %%
chunk_size = 4
for i in range(0, len(x), chunk_size):


    print(x[i:i + chunk_size])
# Out:
# mgww
# jddq
# zqdq
# sstc
# tjjs
# djsd
# srsf
# smfs
# fwwl
# twlw
# hwnh
# hlff
# zddg
# ffwl
# ffbs
# fshf
# shhg
# vvdr
# rltl
# zlnz
# znrr
# nrsn
# nhgn
# nfjn
# nvpn
# nbjj
# nwwr
# cwrr
# hlhv
# lhhm
# zmqz
# qrqt
# qmqp
# mpww
# mssg
# srgr
# gtgm
# tgmt
# gtdt
# vdvm
# vsvs
# bvsb
# vbtt
# hmmf
# tmmd
# nmdd
# crcv
# crrf
# jfhh
# fjhf
# fjll
# cpll
# mcct
# jtrt
# twmt
# wmwf
# frlr
# qlqz
# zpdd
# sqdq
# qgjq
# gjgn
# gwnn
# cjnn
# vsns
# wwbz
# btzz
# flzz
# qsqb
# sbvb
# mbnn
# jpnp
# nnpf
# pmpm
# npmm
# jljt
# ltss
# qnsq
# slst
# swtw
# swwj
# ddvm
# mzlz
# qlzq
# zqjj
# lttm
# trtb
# tmtg
# mtms
# ttrc
# trrs
# qrqv
# vrzr
# crhh
# lnhl
# lbfb
# tthr
# hdhl
# lmwl
# mlgg
# lgsg
# mgsm
# szzp
# rpwp
# fprf
# ftff
# pssj
# zjgz
# jzdd
# qfqm
# mwqw
# vwlv
# lqqt
# btww
# rwtt
# msmp
# pbmm
# pcmc
# tcnn
# hssn
# jncn
# lcnc
# tcjj
# rzrw
# rfwf
# cwff
# czzt
# rtsr
# tstl
# sssl
# jssm
# vssj
# zssr
# qqrc
# qqwl
# qwlw
# ffsf
# lssr
# rzhz
# zhrz
# zdgd
# ppsp
# ...
