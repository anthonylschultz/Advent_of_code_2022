# %%
import pandas as pd

# %%
# read in data file
input = pd.read_csv('data/4.csv', header=None).to_dict('index')

# %%
# convert data to a readable dictionary
d = dict()
for k, v in input.items():
    d[k] = [v[0], v[1]]

# %%
d
# Out:
# {0: ['20-45', '13-44'],
#  1: ['7-8', '8-28'],
#  2: ['3-39', '14-97'],
#  3: ['35-99', '35-98'],
#  4: ['18-49', '17-19'],
#  5: ['33-34', '34-46'],
#  6: ['46-58', '58-75'],
#  7: ['4-93', '25-97'],
#  8: ['92-99', '7-91'],
#  9: ['61-62', '24-61'],
#  10: ['35-62', '34-63'],
#  11: ['85-87', '3-86'],
#  12: ['9-49', '7-48'],
#  13: ['5-87', '87-95'],
#  14: ['3-3', '3-82'],
#  15: ['13-63', '25-62'],
#  16: ['4-99', '1-98'],
#  17: ['72-80', '74-77'],
#  18: ['9-96', '95-97'],
#  19: ['50-68', '51-76'],
#  20: ['34-80', '33-33'],
#  21: ['37-98', '21-37'],
#  22: ['9-71', '10-72'],
#  23: ['40-94', '39-94'],
#  24: ['1-88', '88-92'],
#  25: ['46-47', '46-51'],
#  26: ['14-59', '14-60'],
#  27: ['69-99', '22-95'],
#  28: ['9-66', '9-65'],
#  29: ['62-69', '64-69'],
#  30: ['6-40', '16-70'],
#  31: ['58-97', '9-82'],
#  32: ['12-56', '12-46'],
#  33: ['71-85', '25-70'],
#  34: ['70-86', '86-97'],
#  35: ['47-70', '46-69'],
#  36: ['11-65', '65-66'],
#  37: ['56-58', '57-85'],
# ...
